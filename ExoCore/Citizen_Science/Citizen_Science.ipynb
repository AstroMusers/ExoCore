# %% [markdown]
# # Table of Contents
# 1. [Introduction](#introduction)
# 2. [The Zooniverse](#The_Zooniverse)
#     1. [Galaxy Zoo](#Galaxy_Zoo)
#     2. [Planet Hunters TESS](#Planet_Hunters_TESS)
#         1. [Using the Planet Hunters Analysis Database (PHAD)](#PHAD)
#     3. [Backyard Worlds](#Backyard_Worlds)
#     4. [Project Builder](#Project_Builder)
# 3. [Conclusion](#conclusion)

# %% [markdown]
# # 1. Introduction <a name="introduction"></a>
#
# Citizen science initiatives have significantly contributed to the advancing field of exoplanet research by harnessing the collective power of public participation to analyze datasets. Exoplanet research often entails sorting through extensive data collected by space telescopes like Kepler, TESS, and others. Notable projects such as Galaxy Zoo, Planet Hunters, and Backyard Worlds on the Zooniverse platform allow volunteer participants to identify and characterize possible exoplanet transits or anomalies in light curves. This volunteer involvement complements automated algorithms, enhancing the accuracy of potential exoplanet candidates that might otherwise be overlooked by computers alone. Citizen science provides opportunities for novices to familiarize themselves with exoplanet research.
#
# There are three main ways in which citizen science platforms can benefit new professionals entering the field of exoplanet researchers.
# - Identifying and characterizing data for exposure to exoplanet data processing
# - Opening up a data set and allowing the public to characterize it
# - Utilizing data for independent projects
#
# The following sections will contain discussion on some of the main citizen science platforms in the field currently.

# %% [markdown]
# # 2. [The Zooniverse](https://www.zooniverse.org/) <a name="The_Zooniverse"></a>
#
# Zooniverse is a platform that hosts various citizen science projects. Zooniverse projects typically involve large datasets that are difficult for computers to analyze accurately, but humans can easily recognize patterns or anomalies. Volunteers on Zooniverse help process these datasets by performing tasks such as categorizing images, marking objects of interest, or transcribing text. The projects on Zooniverse cover a wide range of disciplines, including astronomy, biology, ecology, climate science, and more. Zooniverse has the ability to leverage the collective power of a large number of volunteers to accomplish tasks that would be impractical or impossible for a small team of researchers to do on their own. This model has led to scientific discoveries and advancements through providing opportunities for public engagement in science.
#
# ## A. [Galaxy Zoo](https://www.zooniverse.org/projects/zookeeper/galaxy-zoo/) <a name="Galaxy_Zoo"></a>
#
# The Zooniverse kicked off with its first project, Galaxy Zoo, in 2007 with a data set of a few million galaxies from the Sloan Digital Sky Survey. While the Sloan Digital Sky Survey still provides many of the images on the site today, Galaxy Zoo has added images from more distant sky surveys including the Hubble Space Telescope. New data is now being added to Galaxy Zoo rapidly. Recent inclusions incorporate images from the United Kingdom Infrared Telescope (UKIRT), the Dark Energy Camera Legacy Survey (DECaLS), and the Galaxy and Mass Assembly Survey (GAMA). Galaxy Zoo recently classified a dataset of fully simulated galaxies from the Illustris project for the first time. Along with the additions to Galaxy Zoo’s original form, the platform has omitted completed images that are no longer useful to researchers. Past iterations of the platform can be accessed through online archives.
#
# Galaxy Zoo’s diverse array includes surveys on our local group and distant galaxies. By surveying galaxies at different distances, Galaxy Zoo enables researchers to study how galaxies have evolved over time. Comparing local galaxies to those farther away provides researchers with insight into the processes driving galaxy formation and evolution throughout the ages of the universe. As data from more distant galaxies is added to the platform, questions about the relationship between galaxy distance and classification have arisen. In order to establish any dependence of classification on distance, Galaxy Zoo has simulated images of galaxies from different viewing perspectives. Analysis of these images will help discern the effects of redshift on galaxy classification.
#
# ## B. [Planet Hunters TESS](https://www.zooniverse.org/projects/nora-dot-eisner/planet-hunters-tess) <a name="Planet_Hunters_TESS"></a>
#
# Planet Hunters TESS (PHT) is a prominent citizen science project that invites volunteers from around the world to participate in the search for exoplanets. PHT is part of the Zooniverse which hosts a variety of different citizen science programs. The platform takes data from the Transiting Exoplanet Survey Satellite (TESS) which is now an extended mission. During its prime mission, TESS surveyed about 75% (NASA, 2021). PHT has used volunteers to identify exoplanet candidates from these surveys. Volunteers analyze the light curves of surveyed stars looking for dips that could indicate a transiting exoplanet.
#
# Participating in exoplanet classification on PHT can provide new researchers with practical, hands-on experience in analyzing real astronomical data. By working with actual data from space telescopes like TESS, new researchers can become familiar with the types of observations and measurements commonly used in exoplanet studies. Engaging in citizen science projects like PHT provides new researchers with opportunities to connect with experienced scientists and fellow enthusiasts in the field.
#
# This image portrays the site from the perspective of a volunteer identifying a transit as a possible exoplanet candidate
#
# ![Citizen_Science_Figure1.jpg](attachment:Citizen_Science_Figure1.jpg)
#
# PHT makes it extremely easy for volunteers to get involved in classification.
# - Visit the program site
# - Click “classify”
# - Complete the 10 minute tutorial on analyzing light curves
# - Discover exoplanets
#
# ### I. [Using the Planet Hunters Analysis Database (PHAD)](https://mast.stsci.edu/phad/) <a name="PHAD"></a>
#
# PHAD is the public database listing the classifications made by volunteers working on the Planet Hunters TESS Project. The data is accessible throught the Planet Hunters website or programmatically through Jupyter Notebooks on the Zooniverse Github page. All of this data can be used by researchers like you to answer your research questions.
#
# #### Accessing Data on the Website
# On the website, there are two different tabular views. You can learn more about these two different views and the PHAD website [here](https://mast.stsci.edu/phad/about.html).
#
# Transit view organizes subjects based on their subject IDs.
# ![Citizen_Science_PHAD_Transit_Table_View.png](attachment:Citizen_Science_PHAD_Transit_Table_View.png)
#
# User view organizes subjects based on the IDs of the users who identifid them.
# ![Citizen_Science_PHAD_Transit_User_View.jpg](attachment:Citizen_Science_PHAD_Transit_User_View.jpg)
#
# Both viewing options convey most the same information with three informational columns:
# - Center
# - Width
# - Weighted Columns
#
# The two different tabular views only differ in the sense that the transit view contains information on user count (how many users have identified the transit), while the user oriented view only displays data that has been identified by a sufficient number of users. Not all data on fromn the Planet Hunters calssification website is listed in either table. The tables only contain subjects that have been identified as transits by enough reliable viewers. This data can all be used in your own projects as long as you credit the Zooniverse volunteers and Planet Hunters team.
#
# #### Accessing Data Programmatically
# This [page](https://mast.stsci.edu/phad/docs/index.html#getting-started) shows the command line to access all Planet Hunters transit through the command line in a terminal. An example query from the MAST Planet Hunters TESS API documentation to access and load Planet Hunters transit data is also show below.

# %%
GET /api/v0.1/access/transit?flatten_response=false   HTTP/1.1
Host: mast.stsci.edu/phad


HTTP/1.1 200 OK
Content-Type: application/json; charset=UTF-8

{
 "info" :[
    {"name": "transitID", "type": "NUMBER"},
    {"name": "subjectID", "type": "NUMBER"},
    {"name": "center", "type": "NUMBER"},
    {"name": "width", "type": "NUMBER"},
    {"name": "counts", "type": "NUMBER"},
    {"name": "weightedCounts", "type": "NUMBER"},
    {"name": "userCount","type": "NUMBER"},
    {"name": "dateModified","type": null}
    ],
 "data":[
    {
       "transitID": 1,
       "subjectID": 13626,
       "center": 5,
       "width": 10,
       "counts": 5,
       "weightedCounts": 2.5,
       "userCount": 5,
       "dateModified": 2019-01-30 20:18:00.248000
    },
    {
       "transitID": 2,
       "subjectID": 13626,
       "center": 30,
       "width": 5,
       "counts": 8,
       "weightedCounts": 6.1,
       "userCount": 8,
       "dateModified": 2019-01-30 20:18:00.248000
    }
 ]}

POST /api/v0.1/load/transit   HTTP/1.1
Host: mast.stsci.edu/phad

# %% [markdown]
# ## C. [Backyard Worlds](https://www.zooniverse.org/projects/marckuchner/backyard-worlds-planet-9) <a name="Backyard_Worlds"></a>
#
# A final notable project on Zooniverse is Backyard Worlds: Planet 9, a project aimed at discovering new celestial objects in our solar system. Backyard Worlds engages citizen scientists in the search for new objects by having them analyze images taken by NASA's Wide-field Infrared Survey Explorer (WISE) telescope. Participants examine these images to identify moving objects, such as brown dwarfs, low-mass stars, and potentially even the elusive Planet Nine. These celestial bodies can be difficult to detect due to their faintness and distant location, but with the help of volunteers, the project aims to uncover them.
#
# ## D. [Building a project in Zooniverse](https://www.zooniverse.org/lab) <a name="Project_Builder"></a>
#
# While participating in Zooniverse projects like Galaxy Zoo, Planet Hunters, and Backyard Worlds can be beneficial to those entering the field of exoplanet research, perhaps the most substantial feature of Zooniverse, is its project builder. Zooniverse provides an accessible and comprehensive tutorial on its project building feature. With the Project Builder tool, researchers can create a new project by providing information about the scientific objectives, research questions, and datasets they wish to analyze. They can open up a dataset and specify the type of tasks volunteers will perform, such as classifying images, transcribing text, or identifying patterns in data.
#
# ### Project Details
# Zooniverse prompts the user to input details on their project including a name, description, introduction, workflow description, researcher quote, announcement banner, discipline tag, other tags, and external links. Properly outlining the project through these prompts allows researchers to attract and direct volunteers in a manner specific to the individual project
#
# ### About
# Following the project details section in the project builder, the researcher is provided an open field to describe the goals of the project to volunteers. Researchers are encouraged to avoid jargon, so the description is comprehensive to citizen volunteers.
# ![Citizen_Science_Figure2.jpg](attachment:Citizen_Science_Figure2.jpg)
#
# ### Collaborators
# Researchers can add collaborators to their projects and classify their roles based on the extent that they will contribute to the project.
# ![Citizen_Science_Figure3.jpg](attachment:Citizen_Science_Figure3.jpg)
#
# ### Field Guide
# The field guide tab allows researchers to upload a field guide.
#
# ### Tutorial
# Researchers should upload a short tutorial, so that volunteers can quickly and easily get started on contributing to the project.
#
# ### Media
# Media can be uploaded to support the project.
#
# ### Visibility
# While building the project, researchers are able to change the visibility status. The project can be public, so anyone with the URL can access it, or it can be private and visible only to its collaborators.
# ![Citizen_Science_Figure4.jpg](attachment:Citizen_Science_Figure4.jpg)
#
# ### Talk
# Researchers and collaborators can attach discussions to the project, allowing collaborators and volunteers to communicate with each other.
#
# ### Data Exports
# Project data can be exported through the Data Exports tab in CSV format. Discussions can be exported in JSON format.
# ![Citizen_Science_Figure5.jpg](attachment:Citizen_Science_Figure5.jpg)
#
# ### Workflows
# Researchers instruct volunteers on the tasks they want volunteers to perform through workflows.
#
# ### Subject Sets
# Researchers create subject sets of data for the volunteers to analyze.
#
#
# Overall, the Project Builder tool on Zooniverse empowers researchers to create and manage their own citizen science projects, enabling them to leverage the collective efforts of volunteers to address complex scientific questions, analyze large data sets, and advance research in various fields of study.

# %% [markdown]
# # 3. Conclusion
# Throughout this module, you learned about a few major citizen science projects on the Zooniverse. You should now know how to contribute to these projects and build your own utilizing volunteers.
